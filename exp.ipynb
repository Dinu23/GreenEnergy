# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mse_ReLD_0 = [0.7277021408081055] 
mae_ReLD_0 = [0.6361206173896790]
mse_0 = [0.7697566151618958] 
mae_0 = [0.6527844667434692]


mse_ReLD_1 = [0.7446653842926025,0.7501894831657410,0.7455707192420960] 
mae_ReLD_1 = [0.6360610127449036,0.6415103077888489,0.6372223496437073]
mse_1 = [0.7514243125915527,0.7498821020126343,0.7618321871757507]
mae_1 = [0.6435123682022095,0.6476082205772400,0.6510389447212219]

mse_ReLD_2 = [0.7904350757598877,0.7327053546905518,0.7452689409255981] 
mae_ReLD_2 = [0.6581168770790100,0.6331569552421570,0.6335682868957520]
mse_2 = [0.7984192967414856,0.7531306743621826,0.7422478795051575] 
mae_2 = [0.6619216203689575,0.6473764181137085,0.6325163793563843]

mse_ReLD_3 = [0.7380771040916443] 
mae_ReLD_3 = [0.635121762752533]
mse_3 = [0.8148264288902283] 
mae_3 = [0.6768488883972168]

mse_ReLD_4 = [0.6816691756248474] 
mae_ReLD_4 = [0.5963058471679688]
mse_4 = [0.7099259305000305] 
mae_4 = [0.6210290002822876]

mse_ReLD_5 = [0.7090536952018738] 
mae_ReLD_5 = [0.6097619533538818]
mse_5 = [0.732408881187439] 
mae_5 = [0.6342737078666687]

all_mse_ReLD = [np.array(mse_ReLD_0),np.array(mse_ReLD_1),np.array(mse_ReLD_2),np.array(mse_ReLD_3),np.array(mse_ReLD_4),np.array(mse_ReLD_5)]
all_mae_ReLD = [np.array(mae_ReLD_0),np.array(mae_ReLD_1),np.array(mae_ReLD_2),np.array(mae_ReLD_3),np.array(mae_ReLD_4),np.array(mae_ReLD_5)]
all_mse = [np.array(mse_0),np.array(mse_1),np.array(mse_2),np.array(mse_3),np.array(mse_4),np.array(mse_5)]
all_mae = [np.array(mae_0),np.array(mae_1),np.array(mae_2),np.array(mae_3),np.array(mae_4),np.array(mae_5)]

mse_ReLD = np.zeros(6)
mae_ReLD = np.zeros(6)
mse = np.zeros(6)
mae = np.zeros(6)

for i in range(len(all_mse_ReLD)):
   
    mse_ReLD[i] = np.mean(all_mse_ReLD[i])
    mae_ReLD[i] = np.mean(all_mae_ReLD[i])
    mse[i] = np.mean(all_mse[i])
    mae[i] = np.mean(all_mae[i])

print(mse_ReLD)
print(mse)
print(mae_ReLD)
print(mae)
gain_mse = mse-mse_ReLD
gain_mae = mae-mae_ReLD
print(gain_mse)
print(gain_mae)
# Out:
# [0.72770214 0.74680853 0.75613646 0.7380771  0.68166918 0.7090537 ]
# [0.76975662 0.75437953 0.76459928 0.81482643 0.70992593 0.73240888]
# [0.63612062 0.63826456 0.64161404 0.63512176 0.59630585 0.60976195]
# [0.65278447 0.64738651 0.64727147 0.67684889 0.621029   0.63427371]
# [0.04205447 0.00757101 0.00846283 0.07674932 0.02825675 0.02335519]
# [0.01666385 0.00912195 0.00565743 0.04172713 0.02472315 0.02451175]

# %%
plt.figure(figsize=(6,3.5))
plt.ylim((0.65,0.85))
plt.xlabel("Number of External Variable")
plt.ylabel("MSE")
plt.plot(mse_ReLD, label = "MSE with ReLD")
plt.plot(mse,label = "MSE")
plt.legend()
plt.show()

plt.figure(figsize=(6,3.5))
plt.ylim((0.55,0.75))
plt.xlabel("Number of External Variable")
plt.ylabel("MAE")
plt.plot(mae_ReLD, label = "MAE with ReLD")
plt.plot(mae,label = "MAE")
plt.legend()
plt.show()

plt.figure(figsize=(6,3.5))
plt.ylim((0.0,12))
plt.xlabel("Number of External Variable")
plt.ylabel("% Improvement")
plt.plot(gain_mae*100/mse, label = "% MSE ReLD improvement")
plt.plot(gain_mse*100/mae,label = "% MAE ReLD improvement")
plt.legend()
plt.show()

# %%
mse_ReLD_0 = [0.7297592163085938] 
mae_ReLD_0 = [0.6243676543235779]
mse_0 = [0.7872865772247314]
mae_0 = [0.6858164644241333]


mse_ReLD_1 = [0.7203423976898193,0.7109392285346985,0.7351828217506409] 
mae_ReLD_1 = [0.6172481179237366,0.6139671206474304,0.6322357654571533]
mse_1 = [0.7438839077949524,0.7561126947402954,0.7971832156181335]
mae_1 = [0.6455342173576355,0.6420300006866455,0.6602840423583984]

mse_ReLD_2 = [0.7372617125511169,0.7338659763336182,0.6951072812080383] 
mae_ReLD_2 = [0.6270074844360352,0.6313772797584534,0.6090687513351440]
mse_2 = [0.8059616088867188,0.8380537033081055,0.7051131725311279] 
mae_2 = [0.6685900688171387,0.6828765273094177,0.6249926686286926]

mse_ReLD_3 = [0.7249178290367126] 
mae_ReLD_3 = [0.6238861680030823]
mse_3 = [0.7301426920890808] 
mae_3 = [0.6512986421585083]

mse_ReLD_4 = [0.7109301686286926] 
mae_ReLD_4 = [0.6105054020881653]
mse_4 = [0.7660904145240784] 
mae_4 = [0.6582629084587097]

mse_ReLD_5 = [0.7073573470115662] 
mae_ReLD_5 = [0.6179909110069275]
mse_5 = [0.7268217802047730] 
mae_5 = [0.6296177506446838]



all_mse_ReLD = [np.array(mse_ReLD_0),np.array(mse_ReLD_1),np.array(mse_ReLD_2),np.array(mse_ReLD_3),np.array(mse_ReLD_4),np.array(mse_ReLD_5)]
all_mae_ReLD = [np.array(mae_ReLD_0),np.array(mae_ReLD_1),np.array(mae_ReLD_2),np.array(mae_ReLD_3),np.array(mae_ReLD_4),np.array(mae_ReLD_5)]
all_mse = [np.array(mse_0),np.array(mse_1),np.array(mse_2),np.array(mse_3),np.array(mse_4),np.array(mse_5)]
all_mae = [np.array(mae_0),np.array(mae_1),np.array(mae_2),np.array(mae_3),np.array(mae_4),np.array(mae_5)]

mse_ReLD = np.zeros(6)
mae_ReLD = np.zeros(6)
mse = np.zeros(6)
mae = np.zeros(6)

for i in range(len(all_mse_ReLD)):
   
    mse_ReLD[i] = np.mean(all_mse_ReLD[i])
    mae_ReLD[i] = np.mean(all_mae_ReLD[i])
    mse[i] = np.mean(all_mse[i])
    mae[i] = np.mean(all_mae[i])

print(mse_ReLD)
print(mse)
print(mae_ReLD)
print(mae)


gain_mse = mse-mse_ReLD
gain_mae = mae-mae_ReLD
print(gain_mse*100/mse)
print(gain_mae*100/mae)
# Out:
# [0.72975922 0.72215482 0.72207832 0.72491783 0.71093017 0.70735735]
# [0.78728658 0.76572661 0.78304283 0.73014269 0.76609041 0.72682178]
# [0.62436765 0.62115033 0.62248451 0.62388617 0.6105054  0.61799091]
# [0.68581646 0.64928275 0.65881975 0.65129864 0.65826291 0.62961775]
# [7.30704201 5.69025416 7.7855901  0.71559479 7.20022661 2.67802008]
# [8.95994968 4.33284553 5.51520343 4.20889472 7.25508087 1.84665055]

# %%
plt.figure(figsize=(6,3.5))
plt.ylim((0.7,0.8))
plt.xlabel("Number of External Variable")
plt.ylabel("MSE")
plt.plot(mse_ReLD, label = "MSE with ReLD")
plt.plot(mse,label = "MSE")
plt.legend()
plt.show()

plt.figure(figsize=(6,3.5))
plt.ylim((0.6,0.7))
plt.xlabel("Number of External Variable")
plt.ylabel("MAE")
plt.plot(mae_ReLD, label = "MAE with ReLD")
plt.plot(mae,label = "MAE")
plt.legend()
plt.show()

plt.figure(figsize=(6,3.5))
plt.ylim((0.0,10))
plt.xlabel("Number of External Variable")
plt.ylabel("% Improvement")
plt.plot(gain_mae*100/mse, label = "% MSE ReLD improvement")
plt.plot(gain_mse*100/mae,label = "% MAE ReLD improvement")
plt.legend()
plt.show()
